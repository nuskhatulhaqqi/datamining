# %% [markdown]
# ## Diskritisasi (TUGAS 2)
#
# * Carilah data yang bertipe numerik ( data klassifikasi)
#
# * Lakukan proses diskritisasi dengan equal width dan equal frequency
#
# * Lakukan proses diskritisasi dengan basis entropy
#
# * Kumpulkan tugas dengan link github ( web statis dari jupyter book)
#
# * Data dari bunga iris

# %% [markdown]
# # Materi
#
# * Discretization atau binning digunakan untuk mengubah atribut numerik menjadi atribut kategorikal.
# * Perubahan tersebut dilakukan dengan mengkategorikan atribut numerik menjadi beberapa tingkatan atribut kategorikal.
# * Sebagai contoh, apabila terdapat data numerik dengan data berikut: 2, 4, 10, 17, 5, 23, 11, 48, 35, 56, 20
# * Maka, dengan discretization, data tersebut dapat dikategorikan menjadi dua kelompok:
# * Kelompok 1 (Dibawah 25): 2, 4, 5,10, 11, 17, 20, 23
# * Kelompok 2 (Diatas 25): 35, 48, 56
#
# * Mengubah data numerik menjadi kategorikal memungkinkan data tersebut untuk dianalisis dengan menggunakan analisis kategorikal. Sehingga, informasi baru bisa didapatkan dari data tersebut.
#
# * Dalam implementasinya, Discretization memiliki dua pendekatan, equal-width intervals dan equal-frequency intervals.
#
#  *  Equal-width intervals adalah discretization yang membagi data numerik menjadi beberapa kelompok dengan lebar kelompok yang kurang lebih sama besar.
#
#  * Equal-frequency Intervals adalah discretization yang membagi data numerik menjadi beberapa kelompok dengan jumlah anggota yang kurang lebih sama besar.

# %%
import pandas as pd
import numpy as np

# %%
# link data 
dataset_url = 'https://raw.githubusercontent.com/nuskhatulhaqqi/data_mining/main/iris.csv'

# membaca data link
df = pd.read_csv(dataset_url)

#menampilkan data
df.head(10)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
# 5          5.4         3.9          1.7         0.4  Iris-setosa
# 6          4.6         3.4          1.4         0.3  Iris-setosa
# 7          5.0         3.4          1.5         0.2  Iris-setosa
# 8          4.4         2.9          1.4         0.2  Iris-setosa
# 9          4.9         3.1          1.5         0.1  Iris-setosa

# %%
# mengambil data tiap kolom

SEPAL_LENGTH_SERIES = df["sepallength"]
SEPAL_WIDTH_SERIES = df["sepalwidth"]
PETAL_LENGTH_SERIES = df["petallength"]
PETAL_WIDTH_SERIES = df["petalwidth"]

# %% [markdown]
# #Hitung Data
#
# #Definisi discretization
#
# 1. Proses mengubah data bertipe data numeric menjadi data bertipe categorical
#
# 2. Diskritisasi memiliki 2 pendekatan yaitu equal-width intervals dan equal-frequency intervals
#
# 3. equal-width intervals adalah diskritisasi dengan lebar data yang sama
#
# 4. equal-frequency intervals adalah diskritisasi dengan jumlah data yang sama
#
#
# #Cut adalah sebuah method pada library pandas untuk melakukan perhitungan equal width frequency intervals
#
# #kode :
# #pd.cut(series, interval, right=True, label)

# %% [markdown]
# #Sepal Width
#
# #Equal Width Intervals lebar kelopak bunga Iris
#
# #Dikelompokkan menjadi 3 kategori yaitu
#
# #Kategori A
# #Kategori B
# #Kategori C
# #kategori D

# %%
# equal-width intervals

labels = ["A", "B","C","D"]
amount_of_binning = len(labels)

sepal_width_ew_binning = pd.cut(SEPAL_WIDTH_SERIES, amount_of_binning, True, labels)
labelled_sepal_width_ew_binning = sepal_width_ew_binning.value_counts()
interval_sepal_width_ew_binning = pd.cut(SEPAL_WIDTH_SERIES, amount_of_binning, True).value_counts()

# %%
# dataframe of sepal-width and sepal category
df_sw_ew = pd.DataFrame(pd.concat((SEPAL_WIDTH_SERIES, sepal_width_ew_binning), axis=1))

# %%
# ubah nama kolom
df_sw_ew.columns = ["sepalwidth", "class"]

# %%
df_sw_ew
# Out:
#      sepalwidth class
# 0           3.5     C
# 1           3.0     B
# 2           3.2     B
# 3           3.1     B
# 4           3.6     C
# ..          ...   ...
# 145         3.0     B
# 146         2.5     A
# 147         3.0     B
# 148         3.4     C
# 149         3.0     B
#
# [150 rows x 2 columns]

# %%
labelled_sepal_width_ew_binning
# Out:
# B    84
# C    36
# A    24
# D     6
# Name: sepalwidth, dtype: int64

# %%
interval_sepal_width_ew_binning
# Out:
# (2.6, 3.2]      84
# (3.2, 3.8]      36
# (1.998, 2.6]    24
# (3.8, 4.4]       6
# Name: sepalwidth, dtype: int64

# %% [markdown]
# #Petal Width

# %%
# equal-width intervals

labels = ["A", "B", "C","D"]
amount_of_binning = len(labels)

petal_width_ew_binning = pd.cut(PETAL_WIDTH_SERIES, amount_of_binning, True, labels)
labelled_petal_width_ew_binning = petal_width_ew_binning.value_counts()
interval_petal_width_ew_binning = pd.cut(PETAL_WIDTH_SERIES, amount_of_binning, True).value_counts()

# %%
# dataframe of petal-width and petal category
df_pw_ew = pd.DataFrame(pd.concat((PETAL_WIDTH_SERIES, petal_width_ew_binning), axis=1))

# %%
df_pw_ew.columns = ["petalwidth", "class"]

# %%
df_pw_ew
# Out:
#      petalwidth class
# 0           0.2     A
# 1           0.2     A
# 2           0.2     A
# 3           0.2     A
# 4           0.2     A
# ..          ...   ...
# 145         2.3     D
# 146         1.9     C
# 147         2.0     D
# 148         2.3     D
# 149         1.8     C
#
# [150 rows x 2 columns]

# %%
# equal-width intervals with label
labelled_petal_width_ew_binning
# Out:
# A    50
# C    43
# D    29
# B    28
# Name: petalwidth, dtype: int64

# %%
# equal-width intervals without label
interval_petal_width_ew_binning
# Out:
# (0.0976, 0.7]    50
# (1.3, 1.9]       43
# (1.9, 2.5]       29
# (0.7, 1.3]       28
# Name: petalwidth, dtype: int64

# %% [markdown]
# #Sepal Length

# %%
# equal-width intervals

labels = ["A", "B", "C","D"]
amount_of_binning = len(labels)

sepal_length_ew_binning = pd.cut(SEPAL_LENGTH_SERIES, amount_of_binning, True, labels)
labelled_sepal_length_ew_binning = sepal_length_ew_binning.value_counts()
interval_sepal_length_ew_binning = pd.cut(SEPAL_LENGTH_SERIES, amount_of_binning, True).value_counts()

# %%
df_sl_ew = pd.DataFrame(pd.concat((SEPAL_LENGTH_SERIES, sepal_length_ew_binning), axis=1))

# %%
df_sl_ew.columns = ["sepallength", "class"]

# %%
df_sl_ew
# Out:
#     sepallength sepallength
# 0           5.1           A
# 1           4.9           A
# 2           4.7           A
# 3           4.6           A
# 4           5.0           A
# ..          ...         ...
# 145         6.7           C
# 146         6.3           C
# 147         6.5           C
# 148         6.2           C
# 149         5.9           B
#
# [150 rows x 2 columns]

# %%
# equal-width intervals with label
labelled_sepal_length_ew_binning
# Out:
# B    50
# A    45
# C    43
# D    12
# Name: sepallength, dtype: int64

# %%
# equal-width intervals without label
interval_sepal_length_ew_binning
# Out:
# (5.2, 6.1]      50
# (4.296, 5.2]    45
# (6.1, 7.0]      43
# (7.0, 7.9]      12
# Name: sepallength, dtype: int64

# %% [markdown]
# #Petal Length

# %%
# equal-width intervals

labels = ["A", "B", "C","D"]
amount_of_binning = len(labels)

petal_length_ew_binning = pd.cut(PETAL_LENGTH_SERIES, amount_of_binning, True, labels)
labelled_petal_length_ew_binning = petal_length_ew_binning.value_counts()
interval_petal_length_ew_binning = pd.cut(PETAL_LENGTH_SERIES, amount_of_binning, True).value_counts()

# %%
df_pl_ew =  pd.DataFrame(pd.concat((PETAL_LENGTH_SERIES,petal_length_ew_binning), axis=1))

# %%
df_pl_ew.columns = ["petallength", "class"]

# %%
df_pl_ew
# Out:
#      petallength class
# 0            1.4     A
# 1            1.4     A
# 2            1.3     A
# 3            1.5     A
# 4            1.4     A
# ..           ...   ...
# 145          5.2     C
# 146          5.0     C
# 147          5.2     C
# 148          5.4     C
# 149          5.1     C
#
# [150 rows x 2 columns]

# %%
# equal-width intervals binning with label
labelled_petal_length_ew_binning
# Out:
# C    61
# A    50
# D    28
# B    11
# Name: petallength, dtype: int64

# %%
# equal-width intervals out label
interval_petal_length_ew_binning
# Out:
# (3.95, 5.425]     61
# (0.994, 2.475]    50
# (5.425, 6.9]      28
# (2.475, 3.95]     11
# Name: petallength, dtype: int64

# %% [markdown]
# #Qcut adalah sebuah method pada library pandas untuk melakukan perhitungan equal frequency intervals
#
# #CODE:
#
# #pd.qcut(series, interval, label)

# %% [markdown]
# #Sepal Width

# %%
# equal-frequency intervals

labels = ["A", "B", "C","D"]
amount_of_binning = 4

sepal_width_ef_binning = pd.qcut(SEPAL_WIDTH_SERIES, amount_of_binning, labels)
labelled_sepal_width_ef_binning = pd.qcut(SEPAL_WIDTH_SERIES, len(labels), labels).value_counts()
interval_sepal_width_ef_binning = pd.qcut(SEPAL_WIDTH_SERIES, amount_of_binning).value_counts()

# %%
df_sw_ef = pd.DataFrame(pd.concat((SEPAL_WIDTH_SERIES, sepal_width_ef_binning), axis = 1))

# %%
df_sw_ef.columns = ["sepalwidth", "class"]

df_sw_ef
# Out:
#      sepalwidth class
# 0           3.5     D
# 1           3.0     B
# 2           3.2     C
# 3           3.1     C
# 4           3.6     D
# ..          ...   ...
# 145         3.0     B
# 146         2.5     A
# 147         3.0     B
# 148         3.4     D
# 149         3.0     B
#
# [150 rows x 2 columns]

# %%
# equal-frequency intervals binning with label
labelled_sepal_width_ef_binning
# Out:
# A    47
# B    36
# D    36
# C    31
# Name: sepalwidth, dtype: int64

# %%
# equal-frequency intervals out label
interval_sepal_width_ef_binning
# Out:
# (1.999, 2.8]    47
# (2.8, 3.0]      36
# (3.3, 4.4]      36
# (3.0, 3.3]      31
# Name: sepalwidth, dtype: int64

# %% [markdown]
# #Petal Width

# %%
# equal-frequency intervals

labels = ["A", "B", "C","D"]
amount_of_binning = 4

petal_width_ef_binning = pd.qcut(PETAL_WIDTH_SERIES, amount_of_binning, labels)
labelled_petal_width_ef_binning = pd.qcut(PETAL_WIDTH_SERIES, len(labels), labels).value_counts()
interval_petal_width_ef_binning = pd.qcut(PETAL_WIDTH_SERIES, amount_of_binning).value_counts()

# %%
df_pw_ef = pd.DataFrame(pd.concat((PETAL_WIDTH_SERIES, petal_width_ef_binning), axis = 1))

df_pw_ef.columns = ["petalwidth", "class"]

df_pw_ef
# Out:
#      petalwidth class
# 0           0.2     A
# 1           0.2     A
# 2           0.2     A
# 3           0.2     A
# 4           0.2     A
# ..          ...   ...
# 145         2.3     D
# 146         1.9     D
# 147         2.0     D
# 148         2.3     D
# 149         1.8     C
#
# [150 rows x 2 columns]

# %%
# equal-frequency intervals binning with label
labelled_petal_width_ef_binning
# Out:
# A    41
# C    38
# B    37
# D    34
# Name: petalwidth, dtype: int64

# %%
# equal-frequency intervals without label
interval_petal_width_ef_binning
# Out:
# (0.099, 0.3]    41
# (1.3, 1.8]      38
# (0.3, 1.3]      37
# (1.8, 2.5]      34
# Name: petalwidth, dtype: int64

# %% [markdown]
# #Sepal Length

# %%
# equal-frequency intervals

labels = ["A", "B", "C","D"]
amount_of_binning = 4

sepal_length_ef_binning = pd.qcut(SEPAL_LENGTH_SERIES, amount_of_binning, labels)
labelled_sepal_length_ef_binning = pd.qcut(SEPAL_LENGTH_SERIES, len(labels), labels).value_counts()
interval_sepal_length_ef_binning = pd.qcut(SEPAL_LENGTH_SERIES, amount_of_binning).value_counts()

# %%
df_sl_ef = pd.DataFrame(pd.concat((SEPAL_LENGTH_SERIES, sepal_length_ef_binning), axis=1))

df_sl_ef.columns = ["sepallength", "class"]

df_sl_ef
# Out:
#      sepallength class
# 0            5.1     A
# 1            4.9     A
# 2            4.7     A
# 3            4.6     A
# 4            5.0     A
# ..           ...   ...
# 145          6.7     D
# 146          6.3     C
# 147          6.5     D
# 148          6.2     C
# 149          5.9     C
#
# [150 rows x 2 columns]

# %%
# equal-frequency intervals binning with label
labelled_sepal_length_ef_binning
# Out:
# A    41
# B    39
# C    35
# D    35
# Name: sepallength, dtype: int64

# %%
# equal-frequency intervals out label
interval_sepal_length_ef_binning
# Out:
# (4.2989999999999995, 5.1]    41
# (5.1, 5.8]                   39
# (5.8, 6.4]                   35
# (6.4, 7.9]                   35
# Name: sepallength, dtype: int64

# %% [markdown]
# #Petal Length

# %%
# equal-frequency intervals

labels = ["A", "B", "C","D"]
amount_of_binning = 4

petal_length_ef_binning = pd.qcut(PETAL_LENGTH_SERIES, amount_of_binning, labels)
labelled_petal_length_ef_binning = pd.qcut(PETAL_LENGTH_SERIES, len(labels), labels).value_counts()
interval_petal_length_ef_binning = pd.qcut(PETAL_LENGTH_SERIES, amount_of_binning).value_counts()

# %%
df_pl_ef = pd.DataFrame(pd.concat((PETAL_LENGTH_SERIES, petal_length_ef_binning), axis=1))

df_pl_ef.columns = ["petallength", "class"]

df_pl_ef
# Out:
#      petallength class
# 0            1.4     A
# 1            1.4     A
# 2            1.3     A
# 3            1.5     A
# 4            1.4     A
# ..           ...   ...
# 145          5.2     D
# 146          5.0     C
# 147          5.2     D
# 148          5.4     D
# 149          5.1     C
#
# [150 rows x 2 columns]

# %%
# equal-frequency intervals binning with label
labelled_petal_length_ef_binning
# Out:
# A    44
# C    41
# D    34
# B    31
# Name: petallength, dtype: int64

# %%
# equal-frequency intervals out label
interval_petal_length_ef_binning
# Out:
# (0.999, 1.6]    44
# (4.35, 5.1]     41
# (5.1, 6.9]      34
# (1.6, 4.35]     31
# Name: petallength, dtype: int64

# %% [markdown]
# ### Entropy-based Binning
#
# 1.   Metode untuk mengelompokkan data *numeric* menjadi *categorical*
# 2.   Pengelompokkan dengan mencari jumlah pembagi yang terabaik
# 3.   Hasil pengelompokkan terbaik adalah dengan *entropy gain* yang paling besar
#
#
# *  Rumus Entropy
#
# $$
# \begin{align*}
# \displaystyle Entropy(S) &= \sum_{i=0}^{k} -pi \ log_{2} \ pi \\
# \end{align*}
# $$

# %%
# import dari math untuk mendapatkna log 2
from math import log2

# %%
# dataframe about petal width (Equeal Frequency Interval)
df_pw_ef
# Out:
#      petalwidth class
# 0           0.2     A
# 1           0.2     A
# 2           0.2     A
# 3           0.2     A
# 4           0.2     A
# ..          ...   ...
# 145         2.3     D
# 146         1.9     D
# 147         2.0     D
# 148         2.3     D
# 149         1.8     C
#
# [150 rows x 2 columns]

# %%
# dataframe
target_data = df_pw_ef
target_data
# Out:
#      petalwidth class
# 0           0.2     A
# 1           0.2     A
# 2           0.2     A
# 3           0.2     A
# 4           0.2     A
# ..          ...   ...
# 145         2.3     D
# 146         1.9     D
# 147         2.0     D
# 148         2.3     D
# 149         1.8     C
#
# [150 rows x 2 columns]

# %%
labels = ["A", "B", "C","D"]

# %%
#Fungsi menghitung banyaknya data setiap kategori

def countEveryCategory(data_column, labels, column, category):
    group = data_column.groupby(category).count()
    amount_of_every_category = []
    for label in labels:
        amount_of_every_category.append(group.loc[label, column])
    return amount_of_every_category

# %%
#Fungsi menghitung banyaknya data setiap kategori berdasarkan nilai pembagi atau *split value* yang diberikan

def split(split_value, data_column, labels, col, category):
    less_group = data_column[data_column[col] < split_value]
    greater_group = data_column[data_column[col] >= split_value]
    
    length_less_group = countEveryCategory(less_group, labels, col, category)
    length_greater_group = countEveryCategory(greater_group, labels, col, category)
    
    return (length_less_group, length_greater_group)

# %% [markdown]
# # Gain
# # Fungsi menghitung perbedaan *gain* antara entropi inisial dengan entropi nilai pembagi yang diberikan
#
# $$Gain(E_{new}) = (E_{initial}) \ - (E_{new})$$

# %%
def count_gain(inisial_entropy, new_entropy):
  return inisial_entropy - new_entropy

# %%
#Fungsi menghitung entropy

def count_entropy(data_target):
    all_prob = []
    for prob in data_target:
        if (prob/sum(data_target) != 0):
            all_prob.append(prob/sum(data_target) * log2(prob/sum(data_target)))
        else:
            all_prob.append(0)
    return -(sum(all_prob))

# %% [markdown]
# # Fungsi Entropy
# # Fungsi menghitung Info entropy berdasarkan nilai pembagi atau *split value* yang diberikan
#
# $$ Info_A(D) = \frac{|D_1|}{|D|} Entropy (D_1)\frac{|D_2|}{|D|}+ Entropy (D_2)$$

# %%
def info(d, data_target):
    temp = []
    for value in d:
        temp.append((sum(value) / data_target.shape[0]) * count_entropy(value))
    return sum(temp)

# %% [markdown]
# # PENERAPAN
#
#
# *   Hitung target *entropy*
# *   Hitung target *entropy* dengan *split value*
# *   Hitung *entropy gain*

# %%
# entropy data target
initial_data_target_entropy = count_entropy(countEveryCategory(target_data, labels, target_data.columns[0], target_data.columns[1]))

# %%
# count Entropy for the target given a split value, split value = 0.5
entropy_data_target_1 = info(split(0.5, target_data, labels, target_data.columns[0], target_data.columns[1]), target_data)

# %%
# information gain (entropy data target and entropy_data_target_1)
count_gain(initial_data_target_entropy, entropy_data_target_1)
# Out:
# 0.7317709763537443
