# %% [markdown]
# # TUGAS 2

# %%
prinbt('Tugas2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c029881d1d95> in <module>
# ----> 1 prinbt('Tugas2')
#
# NameError: name 'prinbt' is not defined
